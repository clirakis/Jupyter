# %% [markdown]
# Plot Hantek scope data.  <br>
# <u> Modified </u>    <u> By </u>    <u> Reason </u> <br>
# 10-Dec-23    CBL    Original <br>
# <hr>
# References: <br>
# <a href=https://pandas.pydata.org/docs/getting_started/index.html#getting-started> pandas </a> <br>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
PMT = pd.read_csv("Scope/231210_1610.csv")
PMT.plot("t / s", "CH1 / V")
# Out:
# <Axes: xlabel='t / s'>

# %% [markdown]
# Not exactly the best for format saving.
