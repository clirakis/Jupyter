# %% [markdown]
# Plot thermocouple data from house to determine where heating issues are. <br>
# <u> Modified </u>    <u> By </u>    <u> Reason </u> <br>
# 05-Dec-23    CBL    Original <br>
# <hr>
# References: <br>
# https://pandas.pydata.org/docs/getting_started/index.html#getting-started <br>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
Bookcase = pd.read_csv("231205_Bookcase.csv")
Bookcase.plot("Start Time", "Avg (C)")
# Out:
# <Axes: xlabel='Start Time'>

# %%
Thermostat = pd.read_csv("231205_Thermostat.csv")
Thermostat.plot("Start Time", "Avg (C)")
# Out:
# <Axes: xlabel='Start Time'>

# %%
primary = Thermostat["Avg (C)"]
x = primary.to_numpy()
secondary = Bookcase["Avg (C)"]
y = secondary.to_numpy()
plt.plot(x[0:1226],y[0:1226], '.')
