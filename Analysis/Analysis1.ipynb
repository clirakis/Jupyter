# %% [markdown]
# Plot thermocouple data from DI2008 stored in csv format with DateTimestamp. <br>
# <hr>
# 12-Mar-23   CBL  Original
# <hr>
# <ul>
# <li> https://pandas.pydata.org</li>
# <li> xxx</li>
# </ul>

# %%
import numpy as np               # numpy is all the numerical stuff
import matplotlib.pyplot as plt  # I happen to always include this so I can make plots
import pandas as pd

# %%
#df = pd.read_csv('20230312_112941TC.csv') # read thermocouple data
df = pd.read_csv('20230312_115642TC.csv', parse_dates=["DATIME"])
print(df)
# Out:
#                     DATIME     TC0     TC1   TC2   TC3   TC4   TC5   TC6   TC7
# 0  2023-03-12 11:56:43.155  17.495  17.230   nan   nan   nan   nan   nan   nan
# 1  2023-03-12 11:56:43.858  17.431  17.239   nan   nan   nan   nan   nan   nan
# 2  2023-03-12 11:56:44.660  17.459  17.266   nan   nan   nan   nan   nan   nan
# 3  2023-03-12 11:56:45.463  17.486  17.266   nan   nan   nan   nan   nan   nan
# 4  2023-03-12 11:56:46.265  17.422  17.239   nan   nan   nan   nan   nan   nan
# 5  2023-03-12 11:56:47.068  17.513  17.257   nan   nan   nan   nan   nan   nan
# 6  2023-03-12 11:56:47.870  17.459  17.220   nan   nan   nan   nan   nan   nan
# 7  2023-03-12 11:56:48.673  17.504  17.294   nan   nan   nan   nan   nan   nan
# 8  2023-03-12 11:56:49.476  17.459  17.239   nan   nan   nan   nan   nan   nan
# 9  2023-03-12 11:56:50.278  17.440  17.230   nan   nan   nan   nan   nan   nan
# 10 2023-03-12 11:56:51.080  17.459  17.257   nan   nan   nan   nan   nan   nan
# ...

# %%
df.plot(x="DATIME", y="TC1")
# Out:
# <AxesSubplot:xlabel='DATIME'>
