# %%
from IPython.display import display, Math, Latex
display(Math(r'\sqrt{a^2 + b^2}'))
# Out:
# $\displaystyle \sqrt{a^2 + b^2}$

# %%
# This line configures matplotlib to show figures embedded in the notebook, 
# instead of opening a new window for each figure. More about that later. 
# If you are using an old version of IPython, try using '%pylab inline' instead.
# %matplotlib inline

# %%
from pylab import *

# %%
import matplotlib.pyplot as plt
import numpy 
x=numpy.arange(0.,100.,0.01);
y=numpy.cos(x)
First = plt.figure(1)
fig = plt.plot(x,y)
z=[1.1, 10.2, 50.3, 80.9]
q=[1.0, 1.1, 1.2, 1.3]
line, = plt.plot(z,q,'r--')
line.set_antialiased(False) # turn off antialising
points, = plt.plot(z,q,'g^')
plt.title('Test Plot',fontsize=14, color='green')
plt.grid(True)
plt.xlabel('time',fontsize=14, color='red')
plt.ylabel('amplitude', fontsize=14, color='red')
#plt.axis([40, 160, 0, 0.03]) # change axis hi/low
# Out:
# Text(0, 0.5, 'amplitude')
