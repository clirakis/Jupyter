# %% [markdown]
# # Time Series experiments

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
#sns.set(sytle="darkgrid")
import matplotlib.gridspec as gridspec
import matplotlib.mlab as mlab

# %% [markdown]
# # Here is the body of the code, example of using markdown

# %%
# Create a time series, arrange is (start,stop,step,dtype)
x = np.arange(-3.0, 3.0, 0.05)  # A single cycle
#
# Matplotlib examples: https://pythonguides.com/matplotlib-plot-numpy-array/
# In this example we will make a figure with 2 panes.
# some examples can be found here: 
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.figure.html
# https://matplotlib.org/stable/gallery/lines_bars_and_markers/psd_demo.html#sphx-glr-gallery-lines-bars-and-markers-psd-demo-py
# https://matplotlib.org/stable/gallery/lines_bars_and_markers/scatter_hist.html#sphx-glr-gallery-lines-bars-and-markers-scatter-hist-py
#
# Make two side by side frames on a single figure and have the time series and PSD 
# right after. 
#
dt = 0.01                # set time step.
t  = np.arange(0,10,dt)  # give me a set of time points with spacing dt. 
nse = np.random.randn(len(t))
r   = np.exp(-t/0.05)
#
#
cnse = np.convolve(nse, r) * dt
cnse = cnse[:len(t)]
# creating a sine wave with normal noise distribution
s = 0.1 * np.sin(2.0 * np.pi * t) + cnse
fig, (ax0,ax1) = plt.subplots(2,1)
ax0.plot(t,s)
ax1.psd(s, 512,1.0/dt)
plt.show()
