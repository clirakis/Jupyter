# %% [markdown]
# Examples of doman coloring using cplot <br>
# <br>
# Modified    By    Reason <br>
# --------    ---   ------ <br>
# 27-Aug-23.  CBL.  Original <br>
# <hr>
# References: <br>
# https://pypi.org/project/cplot/ <br>
# https://github.com/nschloe/cplot/wiki/Gallery <br>
# <hr>

# %%
import numpy as np
import cplot
import matplotlib.pyplot as plt

# %%
def f(z):
    """
    @param input complex number
    """
    return np.sin(z**3) / z

# %%
lt = cplot.plot(
    f,
    (-2.0, +2.0, 400),
    (-2.0, +2.0, 400),
    # abs_scaling=lambda x: x / (x + 1),  # how to scale the lightness in domain coloring
    # contours_abs=2.0,
    # contours_arg=(-np.pi / 2, 0, np.pi / 2, np.pi),
    # emphasize_abs_contour_1: bool = True,
    # add_colorbars: bool = True,
    # add_axes_labels: bool = True,
    # saturation_adjustment: float = 1.28,
    # min_contour_length = None,
    # linewidth = None,
)
plt.show()

# %%
def g(z):
    return z

# %%
# Would like to know how to rotate the graph 
lt = cplot.plot(
    g,
    (-3.0, +3.0, 400),
    (-3.0, +3.0, 400),
    abs_scaling=lambda x: 1.05*x/(x+1),
    #abs_scaling=lambda x: x / (x + 1),  # how to scale the lightness in domain coloring
    contours_abs=2.0,
    contours_arg=(-np.pi/2, 0, np.pi / 2, np.pi/2),
    #contours_arg=(-np.pi / 2, 0, np.pi / 2, np.pi),
    # emphasize_abs_contour_1: bool = True,
    # add_colorbars: bool = True,
    # add_axes_labels: bool = True,
    saturation_adjustment = 4.0,
    # min_contour_length = None,
    # linewidth = None,
)
plt.show()
